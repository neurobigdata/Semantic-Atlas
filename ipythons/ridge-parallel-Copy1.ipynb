# %%
import pandas as pd
import numpy as np
import nibabel as nib
from copy import copy
import logging
from utils import mult_diag, counter
from multiprocessing import Pool
import pickle

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
with open("srt/stimulus.pcl", 'rb') as f:
    stimulus = pickle.load(f)

# %%
mri = np.load("fmri/mri_all1.npy")

# %%
logger = logging.getLogger('bu')

# %%
zs = lambda v: (v-v.mean(0))/v.std(0) ## z-score function

def ridge_corr(Rstim, Pstim, Rresp, Presp, alphas, normalpha=False, dtype=np.single, corrmin=0.2,
               singcutoff=1e-10, use_corr=True, logger=logging.getLogger("ridge_corr")):
    """Uses ridge regression to find a linear transformation of [Rstim] that approximates [Rresp].
    Then tests by comparing the transformation of [Pstim] to [Presp]. This procedure is repeated
    for each regularization parameter alpha in [alphas]. The correlation between each prediction and
    each response for each alpha is returned. Note that the regression weights are NOT returned.

    Parameters
    ----------
    Rstim : array_like, shape (TR, N)
        Training stimuli with TR time points and N features. Each feature should be Z-scored across time.
    Pstim : array_like, shape (TP, N)
        Test stimuli with TP time points and N features. Each feature should be Z-scored across time.
    Rresp : array_like, shape (TR, M)
        Training responses with TR time points and M responses (voxels, neurons, what-have-you).
        Each response should be Z-scored across time.
    Presp : array_like, shape (TP, M)
        Test responses with TP time points and M responses.
    alphas : list or array_like, shape (A,)
        Ridge parameters to be tested. Should probably be log-spaced. np.logspace(0, 3, 20) works well.
    normalpha : boolean
        Whether ridge parameters should be normalized by the Frobenius norm of Rstim. Good for
        comparing models with different numbers of parameters.
    dtype : np.dtype
        All data will be cast as this dtype for computation. np.single is used by default for memory
        efficiency.
    corrmin : float in [0..1]
        Purely for display purposes. After each alpha is tested, the number of responses with correlation
        greater than corrmin minus the number of responses with correlation less than negative corrmin
        will be printed. For long-running regressions this vague metric of non-centered skewness can
        give you a rough sense of how well the model is working before it's done.
    singcutoff : float
        The first step in ridge regression is computing the singular value decomposition (SVD) of the
        stimulus Rstim. If Rstim is not full rank, some singular values will be approximately equal
        to zero and the corresponding singular vectors will be noise. These singular values/vectors
        should be removed both for speed (the fewer multiplications the better!) and accuracy. Any
        singular values less than singcutoff will be removed.
    use_corr : boolean
        If True, this function will use correlation as its metric of model fit. If False, this function
        will instead use variance explained (R-squared) as its metric of model fit. For ridge regression
        this can make a big difference -- highly regularized solutions will have very small norms and
        will thus explain very little variance while still leading to high correlations, as correlation
        is scale-free while R**2 is not.

    Returns
    -------
    Rcorrs : array_like, shape (A, M)
        The correlation between each predicted response and each column of Presp for each alpha.
    
    """
    ## Calculate SVD of stimulus matrix
    #logging.basicConfig(filename='example.log',level=logging.DEBUG)
    
    logger.info("Doing SVD...")
    try:
        U,S,Vh = np.linalg.svd(Rstim, full_matrices=False)
    except np.linalg.LinAlgError, e:
        logger.info("NORMAL SVD FAILED, trying more robust dgesvd..")
        from text.regression.svd_dgesvd import svd_dgesvd
        U,S,Vh = svd_dgesvd(Rstim, full_matrices=False)

    ## Truncate tiny singular values for speed
    origsize = S.shape[0]
    ngoodS = np.sum(S>singcutoff)
    nbad = origsize-ngoodS
    U = U[:,:ngoodS]
    S = S[:ngoodS]
    Vh = Vh[:ngoodS]
    logger.info("Dropped %d tiny singular values.. (U is now %s)"%(nbad, str(U.shape)))

    ## Normalize alpha by the Frobenius norm
    #frob = np.sqrt((S**2).sum()) ## Frobenius!
    frob = S[0]
    #frob = S.sum()
    logger.info("Training stimulus has Frobenius norm: %0.03f"%frob)
    if normalpha:
        nalphas = alphas * frob
    else:
        nalphas = alphas

    ## Precompute some products for speed
    UR = np.dot(U.T, Rresp) ## Precompute this matrix product for speed
    PVh = np.dot(Pstim, Vh.T) ## Precompute this matrix product for speed
    
    #Prespnorms = np.apply_along_axis(np.linalg.norm, 0, Presp) ## Precompute test response norms
    zPresp = zs(Presp)
    Prespvar = Presp.var(0)
    Rcorrs = [] ## Holds training correlations for each alpha
    for na, a in zip(nalphas, alphas):
        #D = np.diag(S/(S**2+a**2)) ## Reweight singular vectors by the ridge parameter 
        D = S/(S**2+na**2) ## Reweight singular vectors by the (normalized?) ridge parameter
        
        pred = np.dot(mult_diag(D, PVh, left=False), UR) ## Best (1.75 seconds to prediction in test)
        # pred = np.dot(mult_diag(D, np.dot(Pstim, Vh.T), left=False), UR) ## Better (2.0 seconds to prediction in test)
        
        # pvhd = reduce(np.dot, [Pstim, Vh.T, D]) ## Pretty good (2.4 seconds to prediction in test)
        # pred = np.dot(pvhd, UR)
        
        # wt = reduce(np.dot, [Vh.T, D, UR]).astype(dtype) ## Bad (14.2 seconds to prediction in test)
        # wt = reduce(np.dot, [Vh.T, D, U.T, Rresp]).astype(dtype) ## Worst
        # pred = np.dot(Pstim, wt) ## Predict test responses

        if use_corr:
            #prednorms = np.apply_along_axis(np.linalg.norm, 0, pred) ## Compute predicted test response norms
            #Rcorr = np.array([np.corrcoef(Presp[:,ii], pred[:,ii].ravel())[0,1] for ii in range(Presp.shape[1])]) ## Slowly compute correlations
            #Rcorr = np.array(np.sum(np.multiply(Presp, pred), 0)).squeeze()/(prednorms*Prespnorms) ## Efficiently compute correlations
            Rcorr = (zPresp*zs(pred)).mean(0)
        else:
            ## Compute variance explained
            resvar = (Presp-pred).var(0)
            Rcorr = np.clip(1-(resvar/Prespvar), 0, 1)
            
        #Rcorr[np.isnan(Rcorr)] = 0.
        Rcorrs.append(Rcorr)
        
        log_template = "Training: alpha=%0.3f, mean corr=%0.5f, max corr=%0.5f, over-under(%0.2f)=%d"
        log_msg = log_template % (a,
                                  np.mean(Rcorr),
                                  np.max(Rcorr),
                                  corrmin,
                                  (Rcorr>corrmin).sum()-(-Rcorr>corrmin).sum())
        if logger is not None:
            logger.info(log_msg)
        else:
            print log_msg
    
    return Rcorrs

# %%
coordinates = [(x, y, z) for x in range(20, 160, 3) for y in range(20, 160, 3) for z in range(4, 36, 4)]

# %%
def do_ridge(triple):
    print "processing ", triple
    try:
        res = ridge_corr(stimulus[:-500], stimulus[-500:],
                         mri[triple[0], triple[1], triple[2]][:-500],
                         mri[triple[0], triple[1], triple[2]][-500:],
                         range(30, 200, 10))
    except Exception as e:
        print e

    return res

# %%
p = Pool(16)
result = p.map(do_ridge, coordinates)
# Out:
# processing  (20, 20, 4)
# processing  (20, 122, 24)
# processing  (32, 77, 28)
# processing  (26, 47, 32)
# processing  (26, 152, 20)
# processing  (35, 41, 16)
# processing  (38, 107, 24)
# processing  (29, 116, 8)
# processing  (35, 146, 4)
# processing  (44, 32, 32)
# processing  (47, 101, 8)
# processing  (50, 62, 28)
# processing  (44, 137, 20)
# processing  (53, 26, 16)
# processing  (23, 86, 12)
# processing  (41, 71, 12)
# processing  (50, 62, 32)
# processing  (23, 86, 16)
# processing  (29, 116, 12)
# processing  (35, 41, 20)
# processing  (53, 26, 20)
# processing  (41, 71, 16)
# processing  (26, 50, 4)
# processing  (32, 77, 32)
# processing  (47, 101, 12)
# processing  (20, 20, 8)
# processing  (44, 35, 4)
# processing  (26, 152, 24)
# processing  (35, 146, 8)
# processing  (20, 122, 28)
# processing  (38, 107, 28)
# processing  (44, 137, 24)
# processing  (41, 71, 20)
# processing  (29, 116, 16)
# processing  (20, 20, 12)
# processing  (35, 41, 24)
# processing  (32, 80, 4)
# processing  (47, 101, 16)
# processing  (23, 86, 20)
# processing  (26, 50, 8)
# processing  (53, 26, 24)
# processing  (44, 35, 8)
# processing  (20, 122, 32)
# processing  (50, 65, 4)
# processing  (35, 146, 12)
# processing  (38, 107, 32)
# processing  (26, 152, 28)
# processing  (44, 137, 28)
# processing  (41, 71, 24)
# processing  (26, 50, 12)
# processing  (47, 101, 20)
# processing  (35, 41, 28)
# processing  (20, 125, 4)
# processing  (20, 20, 16)
# processing  (23, 86, 24)
# processing  (53, 26, 28)
# processing  (44, 35, 12)
# processing  (50, 65, 8)
# processing  (32, 80, 8)
# processing  (29, 116, 20)
# processing  (26, 152, 32)
# processing  (44, 137, 32)
# processing  (35, 146, 16)
# processing  (38, 110, 4)
# processing  (41, 71, 28)
# processing  (47, 101, 24)
# processing  (44, 35, 16)
# processing  (26, 50, 16)
# processing  (20, 125, 8)
# processing  (20, 20, 20)
# processing  (23, 86, 28)
# processing  (53, 26, 32)
# processing  (35, 41, 32)
# processing  (35, 146, 20)
# processing  (50, 65, 12)
# processing  (26, 155, 4)
# processing  (32, 80, 12)
# processing  (44, 140, 4)
# processing  (38, 110, 8)
# processing  (29, 116, 24)
# processing  (20, 20, 24)
# processing  (53, 29, 4)
# processing  (41, 71, 32)
# processing  (23, 86, 32)
# processing  (44, 35, 20)
# processing  (26, 155, 8)
# processing  (26, 50, 20)
# processing  (50, 65, 16)
# processing  (20, 125, 12)
# processing  (32, 80, 16)
# processing  (35, 44, 4)
# processing  (38, 110, 12)
# processing  (47, 101, 28)
# processing  (35, 146, 24)
# processing  (44, 140, 8)
# processing  (29, 116, 28)
# processing  (20, 20, 28)
# processing  (41, 74, 4)
# processing  (23, 89, 4)
# processing  (26, 155, 12)
# processing  (50, 65, 20)
# processing  (53, 29, 8)
# processing  (44, 35, 24)
# processing  (32, 80, 20)
# processing  (44, 140, 12)
# processing  (26, 50, 24)
# processing  (20, 125, 16)
# processing  (35, 44, 8)
# processing  (38, 110, 16)
# processing  (35, 146, 28)
# processing  (47, 101, 32)
# processing  (29, 116, 32)
# processing  (20, 20, 32)
# processing  (23, 89, 8)
# processing  (41, 74, 8)
# processing  (26, 155, 16)
# processing  (53, 29, 12)
# processing  (50, 65, 24)
# processing  (35, 146, 32)
# processing  (44, 140, 16)
# processing  (32, 80, 24)
# processing  (35, 44, 12)
# processing  (20, 125, 20)
# processing  (44, 35, 28)
# processing  (26, 50, 28)
# processing  (47, 104, 4)
# processing  (29, 119, 4)
# processing  (38, 110, 20)
# processing  (23, 89, 12)
# processing  (20, 23, 4)
# processing  (35, 149, 4)
# processing  (41, 74, 12)
# processing  (53, 29, 16)
# processing  (26, 155, 20)
# processing  (44, 140, 20)
# processing  (32, 80, 28)
# processing  (50, 65, 28)
# processing  (35, 44, 16)
# processing  (44, 35, 32)
# processing  (20, 125, 24)
# processing  (26, 50, 32)
# processing  (29, 119, 8)
# processing  (47, 104, 8)
# processing  (38, 110, 24)
# processing  (20, 23, 8)
# processing  (23, 89, 16)
# processing  (53, 29, 20)
# processing  (26, 155, 24)
# processing  (35, 149, 8)
# processing  (41, 74, 16)
# processing  (44, 38, 4)
# processing  (32, 80, 32)
# processing  (20, 125, 28)
# processing  (44, 140, 24)
# processing  (29, 119, 12)
# processing  (26, 53, 4)
# processing  (35, 44, 20)
# processing  (50, 65, 32)
# processing  (47, 104, 12)
# processing  (38, 110, 28)
# processing  (23, 89, 20)
# processing  (44, 38, 8)
# processing  (53, 29, 24)
# processing  (41, 74, 20)
# processing  (20, 23, 12)
# processing  (32, 83, 4)
# processing  (26, 155, 28)
# processing  (29, 119, 16)
# processing  (35, 149, 12)
# processing  (20, 125, 32)
# processing  (44, 140, 28)
# processing  (35, 44, 24)
# processing  (47, 104, 16)
# processing  (26, 53, 8)
# processing  (50, 68, 4)
# processing  (38, 110, 32)
# processing  (32, 83, 8)
# processing  (53, 29, 28)
# processing  (41, 74, 24)
# processing  (44, 38, 12)
# processing  (35, 149, 16)
# processing  (20, 23, 16)
# processing  (26, 155, 32)
# processing  (23, 89, 24)
# processing  (35, 44, 28)
# processing  (29, 119, 20)
# processing  (44, 140, 32)
# processing  (26, 53, 12)
# processing  (47, 104, 20)
# processing  (20, 128, 4)
# processing  (50, 68, 8)
# processing  (38, 113, 4)
# processing  (26, 158, 4)
# processing  (32, 83, 12)
# processing  (44, 38, 16)
# processing  (53, 29, 32)
# processing  (23, 89, 28)
# processing  (35, 149, 20)
# processing  (35, 44, 32)
# processing  (29, 119, 24)
# processing  (41, 74, 28)
# processing  (44, 143, 4)
# processing  (20, 23, 20)
# processing  (20, 128, 8)
# processing  (26, 53, 16)
# processing  (50, 68, 12)
# processing  (47, 104, 24)
# processing  (38, 113, 8)
# processing  (32, 83, 16)
# processing  (53, 32, 4)
# processing  (26, 158, 8)
# processing  (44, 38, 20)
# processing  (44, 143, 8)
# processing  (23, 89, 32)
# processing  (35, 149, 24)
# processing  (35, 47, 4)
# processing  (20, 23, 24)
# processing  (41, 74, 32)
# processing  (29, 119, 28)
# processing  (20, 128, 12)
# processing  (50, 68, 16)
# processing  (26, 53, 20)
# processing  (47, 104, 28)
# processing  (38, 113, 12)
# processing  (26, 158, 12)
# processing  (32, 83, 20)
# processing  (53, 32, 8)
# processing  (23, 92, 4)
# processing  (35, 149, 28)
# processing  (44, 143, 12)
# processing  (29, 119, 32)
# processing  (35, 47, 8)
# processing  (20, 128, 16)
# processing  (41, 77, 4)
# processing  (26, 53, 24)
# processing  (44, 38, 24)
# processing  (50, 68, 20)
# processing  (20, 23, 28)
# processing  (47, 104, 32)
# processing  (38, 113, 16)
# processing  (35, 149, 32)
# processing  (32, 83, 24)
# processing  (26, 158, 16)
# processing  (29, 122, 4)
# processing  (23, 92, 8)
# processing  (53, 32, 12)
# processing  (41, 77, 8)
# processing  (44, 143, 16)
# processing  (26, 53, 28)
# processing  (20, 23, 32)
# processing  (20, 128, 20)
# processing  (44, 38, 28)
# processing  (35, 47, 12)
# processing  (50, 68, 24)
# processing  (38, 113, 20)
# processing  (47, 107, 4)
# processing  (32, 83, 28)
# processing  (26, 158, 20)
# processing  (35, 152, 4)
# processing  (23, 92, 12)
# processing  (44, 143, 20)
# processing  (29, 122, 8)
# processing  (41, 77, 12)
# processing  (26, 53, 32)
# processing  (53, 32, 16)
# processing  (35, 47, 16)
# processing  (44, 38, 32)
# processing  (38, 113, 24)
# processing  (20, 128, 24)
# processing  (50, 68, 28)
# processing  (20, 26, 4)
# processing  (47, 107, 8)
# processing  (32, 83, 32)
# processing  (35, 152, 8)
# processing  (26, 158, 24)
# processing  (44, 143, 24)
# processing  (29, 122, 12)
# processing  (35, 47, 20)
# processing  (23, 92, 16)
# processing  (44, 41, 4)
# processing  (26, 56, 4)
# processing  (41, 77, 16)
# processing  (50, 68, 32)
# processing  (20, 128, 28)
# processing  (53, 32, 20)
# processing  (47, 107, 12)
# processing  (38, 113, 28)
# processing  (20, 26, 8)
# processing  (35, 152, 12)
# processing  (32, 86, 4)
# processing  (26, 158, 28)
# processing  (44, 143, 28)
# processing  (35, 47, 24)
# processing  (44, 41, 8)
# processing  (29, 122, 16)
# processing  (23, 92, 20)
# processing  (47, 107, 16)
# processing  (41, 77, 20)
# processing  (26, 56, 8)
# processing  (20, 128, 32)
# processing  (38, 113, 32)
# processing  (53, 32, 24)
# processing  (20, 26, 12)
# processing  (50, 71, 4)
# processing  (35, 152, 16)
# processing  (32, 86, 8)
# processing  (26, 158, 32)
# processing  (35, 47, 28)
# processing  (44, 143, 32)
# processing  (41, 77, 24)
# processing  (47, 107, 20)
# processing  (44, 41, 12)
# processing  (38, 116, 4)
# processing  (29, 122, 20)
# processing  (23, 92, 24)
# processing  (20, 131, 4)
# processing  (26, 56, 12)
# processing  (20, 26, 16)
# processing  (53, 32, 28)
# processing  (50, 71, 8)
# processing  (29, 20, 4)
# processing  (35, 152, 20)
# processing  (32, 86, 12)
# processing  (35, 47, 32)
# processing  (44, 146, 4)
# processing  (47, 107, 24)
# processing  (29, 122, 24)
# processing  (41, 77, 28)
# processing  (23, 92, 28)
# processing  (44, 41, 16)
# processing  (38, 116, 8)
# processing  (20, 131, 8)
# processing  (26, 56, 16)
# processing  (50, 71, 12)
# processing  (20, 26, 20)
# processing  (53, 32, 32)
# processing  (29, 20, 8)
# processing  (35, 152, 24)
# processing  (32, 86, 16)
# processing  (35, 50, 4)
# processing  (41, 77, 32)
# processing  (44, 146, 8)
# processing  (23, 92, 32)
# processing  (29, 122, 28)
# processing  (47, 107, 28)
# processing  (38, 116, 12)
# processing  (26, 56, 20)
# processing  (20, 26, 24)
# processing  (44, 41, 20)
# processing  (20, 131, 12)
# processing  (50, 71, 16)
# processing  (53, 35, 4)
# processing  (29, 20, 12)
# processing  (35, 152, 28)
# processing  (32, 86, 20)
# processing  (44, 146, 12)
# processing  (35, 50, 8)
# processing  (41, 80, 4)
# processing  (26, 56, 24)
# processing  (29, 122, 32)
# processing  (20, 131, 16)
# processing  (38, 116, 16)
# processing  (44, 41, 24)
# processing  (23, 95, 4)
# processing  (20, 26, 28)
# processing  (47, 107, 32)
# processing  (53, 35, 8)
# processing  (50, 71, 20)
# processing  (29, 20, 16)
# processing  (32, 86, 24)
# processing  (35, 152, 32)
# processing  (35, 50, 12)
# processing  (44, 146, 16)
# processing  (41, 80, 8)
# processing  (26, 56, 28)
# processing  (29, 125, 4)
# processing  (44, 41, 28)
# processing  (23, 95, 8)
# processing  (20, 131, 20)
# processing  (38, 116, 20)
# processing  (20, 26, 32)
# processing  (47, 110, 4)
# processing  (53, 35, 12)
# processing  (29, 20, 20)
# processing  (50, 71, 24)
# processing  (44, 146, 20)
# processing  (32, 86, 28)
# processing  (35, 50, 16)
# processing  (35, 155, 4)
# processing  (41, 80, 12)
# processing  (26, 56, 32)
# processing  (29, 125, 8)
# processing  (20, 131, 24)
# processing  (23, 95, 12)
# processing  (44, 41, 32)
# processing  (38, 116, 24)
# processing  (53, 35, 16)
# processing  (20, 29, 4)
# processing  (50, 71, 28)
# processing  (47, 110, 8)
# processing  (29, 20, 24)
# processing  (44, 146, 24)
# processing  (35, 155, 8)
# processing  (35, 50, 20)
# processing  (41, 80, 16)
# processing  (32, 86, 32)
# processing  (26, 59, 4)
# processing  (29, 125, 12)
# processing  (20, 131, 28)
# processing  (23, 95, 16)
# processing  (20, 29, 8)
# processing  (53, 35, 20)
# processing  (44, 44, 4)
# processing  (38, 116, 28)
# processing  (50, 71, 32)
# processing  (47, 110, 12)
# processing  (29, 20, 28)
# processing  (35, 155, 12)
# processing  (35, 50, 24)
# processing  (44, 146, 28)
# processing  (26, 59, 8)
# processing  (32, 89, 4)
# processing  (41, 80, 20)
# processing  (29, 125, 16)
# processing  (23, 95, 20)
# processing  (20, 131, 32)
# processing  (38, 116, 32)
# processing  (53, 35, 24)
# processing  (20, 29, 12)
# processing  (44, 44, 8)
# processing  (47, 110, 16)
# processing  (50, 74, 4)
# processing  (35, 155, 16)
# processing  (35, 50, 28)
# processing  (29, 20, 32)
# processing  (44, 146, 32)
# processing  (26, 59, 12)
# processing  (32, 89, 8)
# processing  (41, 80, 24)
# processing  (20, 134, 4)
# processing  (29, 125, 20)
# processing  (23, 95, 24)
# processing  (20, 29, 16)
# processing  (38, 119, 4)
# processing  (53, 35, 28)
# processing  (44, 44, 12)
# processing  (47, 110, 20)
# processing  (50, 74, 8)
# processing  (35, 155, 20)
# processing  (35, 50, 32)
# processing  (29, 23, 4)
# processing  (32, 89, 12)
# processing  (26, 59, 16)
# processing  (20, 134, 8)
# processing  (44, 149, 4)
# processing  (29, 125, 24)
# processing  (20, 29, 20)
# processing  (41, 80, 28)
# processing  (23, 95, 28)
# processing  (53, 35, 32)
# processing  (38, 119, 8)
# processing  (44, 44, 16)
# processing  (47, 110, 24)
# processing  (50, 74, 12)
# processing  (35, 155, 24)
# processing  (29, 23, 8)
# processing  (26, 59, 20)
# processing  (35, 53, 4)
# processing  (32, 89, 16)
# processing  (44, 149, 8)
# processing  (29, 125, 28)
# processing  (20, 29, 24)
# processing  (20, 134, 12)
# processing  (41, 80, 32)
# processing  (38, 119, 12)
# processing  (53, 38, 4)
# processing  (23, 95, 32)
# processing  (50, 74, 16)
# processing  (44, 44, 20)
# processing  (47, 110, 28)
# processing  (35, 155, 28)
# processing  (29, 23, 12)
# processing  (35, 53, 8)
# processing  (32, 89, 20)
# processing  (26, 59, 24)
# processing  (41, 83, 4)
# processing  (20, 134, 16)
# processing  (20, 29, 28)
# processing  (44, 149, 12)
# processing  (38, 119, 16)
# processing  (29, 125, 32)
# processing  (53, 38, 8)
# processing  (23, 98, 4)
# processing  (50, 74, 20)
# processing  (44, 44, 24)
# processing  (35, 155, 32)
# processing  (47, 110, 32)
# processing  (29, 23, 16)
# processing  (35, 53, 12)
# processing  (38, 119, 20)
# processing  (20, 29, 32)
# processing  (41, 83, 8)
# processing  (32, 89, 24)
# processing  (20, 134, 20)
# processing  (26, 59, 28)
# processing  (29, 128, 4)
# processing  (44, 149, 16)
# processing  (23, 98, 8)
# processing  (53, 38, 12)
# processing  (50, 74, 24)
# processing  (44, 44, 28)
# processing  (35, 158, 4)
# processing  (47, 113, 4)
# processing  (38, 119, 24)
# processing  (29, 23, 20)
# processing  (20, 32, 4)
# processing  (20, 134, 24)
# processing  (41, 83, 12)
# processing  (26, 59, 32)
# processing  (35, 53, 16)
# processing  (44, 149, 20)
# processing  (32, 89, 28)
# processing  (53, 38, 16)
# processing  (29, 128, 8)
# processing  (50, 74, 28)
# processing  (23, 98, 12)
# processing  (44, 44, 32)
# processing  (35, 158, 8)
# processing  (47, 113, 8)
# processing  (38, 119, 28)
# processing  (20, 32, 8)
# processing  (20, 134, 28)
# processing  (26, 62, 4)
# processing  (41, 83, 16)
# processing  (29, 23, 24)
# processing  (35, 53, 20)
# processing  (53, 38, 20)
# processing  (32, 89, 32)
# processing  (29, 128, 12)
# processing  (44, 149, 24)
# processing  (44, 47, 4)
# processing  (35, 158, 12)
# processing  (23, 98, 16)
# processing  (50, 74, 32)
# processing  (47, 113, 12)
# processing  (38, 119, 32)
# processing  (20, 32, 12)
# processing  (41, 83, 20)
# processing  (20, 134, 32)
# processing  (53, 38, 24)
# processing  (26, 62, 8)
# processing  (29, 128, 16)
# processing  (29, 23, 28)
# processing  (35, 53, 24)
# processing  (44, 47, 8)
# processing  (50, 77, 4)
# processing  (32, 92, 4)
# processing  (23, 98, 20)
# processing  (44, 149, 28)
# processing  (35, 158, 16)
# processing  (47, 113, 16)
# processing  (38, 122, 4)
# processing  (20, 32, 16)
# processing  (20, 137, 4)
# processing  (41, 83, 24)
# processing  (29, 128, 20)
# processing  (26, 62, 12)
# processing  (23, 98, 24)
# processing  (35, 53, 28)
# processing  (44, 47, 12)
# processing  (50, 77, 8)
# processing  (29, 23, 32)
# processing  (32, 92, 8)
# processing  (53, 38, 28)
# processing  (35, 158, 20)
# processing  (44, 149, 32)
# processing  (38, 122, 8)
# processing  (47, 113, 20)
# processing  (20, 32, 20)
# processing  (41, 83, 28)
# processing  (20, 137, 8)
# processing  (29, 128, 24)
# processing  (26, 62, 16)
# processing  (32, 92, 12)
# processing  (29, 26, 4)
# processing  (35, 53, 32)
# processing  (44, 47, 16)
# processing  (23, 98, 28)
# processing  (50, 77, 12)
# processing  (53, 38, 32)
# processing  (35, 158, 24)
# processing  (44, 152, 4)
# processing  (38, 122, 12)
# processing  (47, 113, 24)
# processing  (41, 83, 32)
# processing  (20, 32, 24)
# processing  (29, 128, 28)
# processing  (26, 62, 20)
# processing  (20, 137, 12)
# processing  (50, 77, 16)
# processing  (23, 98, 32)
# processing  (44, 47, 20)
# processing  (53, 41, 4)
# processing  (29, 26, 8)
# processing  (35, 56, 4)
# processing  (32, 92, 16)
# processing  (35, 158, 28)
# processing  (44, 152, 8)
# processing  (38, 122, 16)
# processing  (41, 86, 4)
# processing  (47, 113, 28)
# processing  (29, 128, 32)
# processing  (20, 32, 28)
# processing  (26, 62, 24)
# processing  (23, 101, 4)
# processing  (20, 137, 16)
# processing  (53, 41, 8)
# processing  (50, 77, 20)
# processing  (35, 56, 8)
# processing  (44, 47, 24)
# processing  (32, 92, 20)
# processing  (29, 26, 12)
# processing  (35, 158, 32)
# processing  (38, 122, 20)
# processing  (44, 152, 12)
# processing  (41, 86, 8)
# processing  (47, 113, 32)
# processing  (29, 131, 4)
# processing  (20, 32, 32)
# processing  (26, 62, 28)
# processing  (44, 47, 28)
# processing  (53, 41, 12)
# processing  (20, 137, 20)
# processing  (23, 101, 8)
# processing  (50, 77, 24)
# processing  (32, 92, 24)
# processing  (35, 56, 12)
# processing  (29, 26, 16)
# processing  (38, 122, 24)
# processing  (38, 20, 4)
# processing  (44, 152, 16)
# processing  (41, 86, 12)
# processing  (47, 116, 4)
# processing  (29, 131, 8)
# processing  (20, 35, 4)
# processing  (26, 62, 32)
# processing  (50, 77, 28)
# processing  (23, 101, 12)
# processing  (44, 47, 32)
# processing  (32, 92, 28)
# processing  (53, 41, 16)
# processing  (20, 137, 24)
# processing  (29, 26, 20)
# processing  (35, 56, 16)
# processing  (38, 20, 8)
# processing  (38, 122, 28)
# processing  (44, 152, 20)
# processing  (41, 86, 16)
# processing  (29, 131, 12)
# processing  (47, 116, 8)
# processing  (26, 65, 4)
# processing  (20, 35, 8)
# processing  (20, 137, 28)
# processing  (23, 101, 16)
# processing  (32, 92, 32)
# processing  (53, 41, 20)
# processing  (50, 77, 32)
# processing  (35, 56, 20)
# processing  (44, 50, 4)
# processing  (38, 122, 32)
# processing  (38, 20, 12)
# processing  (29, 26, 24)
# processing  (44, 152, 24)
# processing  (47, 116, 12)
# processing  (41, 86, 20)
# processing  (29, 131, 16)
# processing  (26, 65, 8)
# processing  (50, 80, 4)
# processing  (20, 137, 32)
# processing  (20, 35, 12)
# processing  (23, 101, 20)
# processing  (53, 41, 24)
# processing  (32, 95, 4)
# processing  (35, 56, 24)
# processing  (44, 50, 8)
# processing  (38, 20, 16)
# processing  (29, 26, 28)
# processing  (38, 125, 4)
# processing  (44, 152, 28)
# processing  (41, 86, 24)
# processing  (47, 116, 16)
# processing  (29, 131, 20)
# processing  (50, 80, 8)
# processing  (23, 101, 24)
# processing  (38, 20, 20)
# processing  (20, 35, 16)
# processing  (26, 65, 12)
# processing  (44, 50, 12)
# processing  (53, 41, 28)
# processing  (35, 56, 28)
# processing  (32, 95, 8)
# processing  (20, 140, 4)
# processing  (38, 125, 8)
# processing  (29, 26, 32)
# processing  (44, 152, 32)
# processing  (47, 116, 20)
# processing  (41, 86, 28)
# processing  (29, 131, 24)
# processing  (50, 80, 12)
# processing  (38, 20, 24)
# processing  (26, 65, 16)
# processing  (23, 101, 28)
# processing  (20, 35, 20)
# processing  (35, 56, 32)
# processing  (32, 95, 12)
# processing  (44, 50, 16)
# processing  (53, 41, 32)
# processing  (44, 155, 4)
# processing  (29, 29, 4)
# processing  (20, 140, 8)
# processing  (38, 125, 12)
# processing  (47, 116, 24)
# processing  (41, 86, 32)
# processing  (29, 131, 28)
# processing  (38, 20, 28)
# processing  (50, 80, 16)
# processing  (32, 95, 16)
# processing  (44, 50, 20)
# processing  (53, 44, 4)
# processing  (26, 65, 20)
# processing  (44, 155, 8)
# processing  (20, 35, 24)
# processing  (38, 125, 16)
# processing  (29, 29, 8)
# processing  (35, 59, 4)
# processing  (23, 101, 32)
# processing  (20, 140, 12)
# processing  (47, 116, 28)
# processing  (41, 89, 4)
# processing  (29, 131, 32)
# processing  (50, 80, 20)
# processing  (38, 20, 32)
# processing  (32, 95, 20)
# processing  (44, 155, 12)
# processing  (20, 35, 28)
# processing  (38, 125, 20)
# processing  (20, 140, 16)
# processing  (44, 50, 24)
# processing  (53, 44, 8)
# processing  (26, 65, 24)
# processing  (29, 29, 12)
# processing  (23, 104, 4)
# processing  (35, 59, 8)
# processing  (47, 116, 32)
# processing  (41, 89, 8)
# processing  (29, 134, 4)
# processing  (50, 80, 24)
# processing  (38, 23, 4)
# processing  (32, 95, 24)
# processing  (53, 44, 12)
# processing  (20, 140, 20)
# processing  (44, 155, 16)
# processing  (44, 50, 28)
# processing  (38, 125, 24)
# processing  (23, 104, 8)
# processing  (26, 65, 28)
# processing  (20, 35, 32)
# processing  (29, 29, 16)
# processing  (35, 59, 12)
# processing  (47, 119, 4)
# processing  (41, 89, 12)
# processing  (29, 134, 8)
# processing  (38, 23, 8)
# processing  (50, 80, 28)
# processing  (44, 50, 32)
# processing  (20, 140, 24)
# processing  (38, 125, 28)
# processing  (23, 104, 12)
# processing  (53, 44, 16)
# processing  (44, 155, 20)
# processing  (32, 95, 28)
# processing  (26, 65, 32)
# processing  (29, 29, 20)
# processing  (35, 59, 16)
# processing  (20, 38, 4)
# processing  (47, 119, 8)
# processing  (41, 89, 16)
# processing  (29, 134, 12)
# processing  (38, 125, 32)
# processing  (20, 140, 28)
# processing  (32, 95, 32)
# processing  (38, 23, 12)
# processing  (50, 80, 32)
# processing  (23, 104, 16)
# processing  (44, 53, 4)
# processing  (44, 155, 24)
# processing  (53, 44, 20)
# processing  (26, 68, 4)
# processing  (20, 38, 8)
# processing  (29, 29, 24)
# processing  (35, 59, 20)
# processing  (47, 119, 12)
# processing  (41, 89, 20)
# processing  (29, 134, 16)
# processing  (32, 98, 4)
# processing  (20, 140, 32)
# processing  (38, 128, 4)
# processing  (44, 155, 28)
# processing  (38, 23, 16)
# processing  (53, 44, 24)
# processing  (50, 83, 4)
# processing  (20, 38, 12)
# processing  (23, 104, 20)
# processing  (44, 53, 8)
# processing  (26, 68, 8)
# processing  (47, 119, 16)
# processing  (29, 29, 28)
# processing  (35, 59, 24)
# processing  (41, 89, 24)
# processing  (29, 134, 20)
# processing  (44, 155, 32)
# processing  (38, 128, 8)
# processing  (32, 98, 8)
# processing  (20, 143, 4)
# processing  (38, 23, 20)
# processing  (50, 83, 8)
# processing  (23, 104, 24)
# processing  (20, 38, 16)
# processing  (29, 29, 32)
# processing  (53, 44, 28)
# processing  (26, 68, 12)
# processing  (44, 53, 12)
# processing  (47, 119, 20)
# processing  (35, 59, 28)
# processing  (41, 89, 28)
# processing  (29, 134, 24)
# processing  (44, 158, 4)
# processing  (38, 23, 24)
# processing  (38, 128, 12)
# processing  (50, 83, 12)
# processing  (20, 143, 8)
# processing  (32, 98, 12)
# processing  (53, 44, 32)
# processing  (23, 104, 28)
# processing  (20, 38, 20)
# processing  (47, 119, 24)
# processing  (29, 32, 4)
# processing  (44, 53, 16)
# processing  (35, 59, 32)
# processing  (26, 68, 16)
# processing  (41, 89, 32)
# processing  (29, 134, 28)
# processing  (38, 23, 28)
# processing  (44, 158, 8)
# processing  (50, 83, 16)
# processing  (20, 38, 24)
# processing  (20, 143, 12)
# processing  (32, 98, 16)
# processing  (38, 128, 16)
# processing  (47, 119, 28)
# processing  (29, 32, 8)
# processing  (44, 53, 20)
# processing  (26, 68, 20)
# processing  (23, 104, 32)
# processing  (53, 47, 4)
# processing  (35, 62, 4)
# processing  (41, 92, 4)
# processing  (38, 23, 32)
# processing  (29, 134, 32)
# processing  (44, 158, 12)
# processing  (32, 98, 20)
# processing  (47, 119, 32)
# processing  (20, 38, 28)
# processing  (20, 143, 16)
# processing  (29, 32, 12)
# processing  (50, 83, 20)
# processing  (53, 47, 8)
# processing  (44, 53, 24)
# processing  (38, 128, 20)
# processing  (23, 107, 4)
# processing  (26, 68, 24)
# processing  (35, 62, 8)
# processing  (41, 92, 8)
# processing  (38, 26, 4)
# processing  (44, 158, 16)
# processing  (29, 137, 4)
# processing  (47, 122, 4)
# processing  (20, 38, 32)
# processing  (50, 83, 24)
# processing  (32, 98, 24)
# processing  (29, 32, 16)
# processing  (23, 107, 8)
# processing  (20, 143, 20)
# processing  (44, 53, 28)
# processing  (53, 47, 12)
# processing  (38, 128, 24)
# processing  (26, 68, 28)
# processing  (41, 92, 12)
# processing  (35, 62, 12)
# processing  (29, 137, 8)
# processing  (47, 122, 8)
# processing  (38, 26, 8)
# processing  (50, 83, 28)
# processing  (20, 41, 4)
# processing  (44, 158, 20)
# processing  (29, 32, 20)
# processing  (32, 98, 28)
# processing  (44, 53, 32)
# processing  (53, 47, 16)
# processing  (41, 92, 16)
# processing  (20, 143, 24)
# processing  (26, 68, 32)
# processing  (23, 107, 12)
# processing  (38, 128, 28)
# processing  (35, 62, 16)
# processing  (29, 137, 12)
# processing  (44, 158, 24)
# processing  (47, 122, 12)
# processing  (50, 83, 32)
# processing  (20, 41, 8)
# processing  (26, 71, 4)
# processing  (38, 26, 12)
# processing  (38, 128, 32)
# processing  (53, 47, 20)
# processing  (20, 143, 28)
# processing  (32, 98, 32)
# processing  (29, 32, 24)
# processing  (41, 92, 20)
# processing  (44, 56, 4)
# processing  (23, 107, 16)
# processing  (35, 62, 20)
# processing  (47, 122, 16)
# processing  (44, 158, 28)
# processing  (20, 41, 12)
# processing  (29, 137, 16)
# processing  (38, 26, 16)
# processing  (50, 86, 4)
# processing  (53, 47, 24)
# processing  (38, 131, 4)
# processing  (26, 71, 8)
# processing  (29, 32, 28)
# processing  (20, 143, 32)
# processing  (32, 101, 4)
# processing  (41, 92, 24)
# processing  (44, 56, 8)
# processing  (23, 107, 20)
# processing  (35, 62, 24)
# processing  (38, 131, 8)
# processing  (47, 122, 20)
# processing  (20, 41, 16)
# processing  (50, 86, 8)
# processing  (38, 26, 20)
# processing  (44, 158, 32)
# processing  (29, 137, 20)
# processing  (53, 47, 28)
# processing  (29, 32, 32)
# processing  (26, 71, 12)
# processing  (32, 101, 8)
# processing  (20, 146, 4)
# processing  (41, 92, 28)
# processing  (44, 56, 12)
# processing  (23, 107, 24)
# processing  (35, 62, 28)
# processing  (38, 131, 12)
# processing  (47, 122, 24)
# processing  (50, 86, 12)
# processing  (38, 26, 24)
# processing  (47, 20, 4)
# processing  (20, 41, 20)
# processing  (29, 137, 24)
# processing  (32, 101, 12)
# processing  (41, 92, 32)
# processing  (29, 35, 4)
# processing  (53, 47, 32)
# processing  (20, 146, 8)
# processing  (26, 71, 16)
# processing  (44, 56, 16)
# processing  (23, 107, 28)
# processing  (35, 62, 32)
# processing  (38, 131, 16)
# processing  (47, 122, 28)
# processing  (50, 86, 16)
# processing  (38, 26, 28)
# processing  (32, 101, 16)
# processing  (29, 35, 8)
# processing  (53, 50, 4)
# processing  (20, 41, 24)
# processing  (29, 137, 28)
# processing  (47, 20, 8)
# processing  (41, 95, 4)
# processing  (26, 71, 20)
# processing  (44, 56, 20)
# processing  (20, 146, 12)
# processing  (23, 107, 32)
# processing  (35, 65, 4)
# processing  (38, 131, 20)
# processing  (47, 122, 32)
# processing  (50, 86, 20)
# processing  (47, 20, 12)
# processing  (32, 101, 20)
# processing  (53, 50, 8)
# processing  (29, 137, 32)
# processing  (20, 41, 28)
# processing  (41, 95, 8)
# processing  (26, 71, 24)
# processing  (38, 26, 32)
# processing  (29, 35, 12)
# processing  (20, 146, 16)
# processing  (44, 56, 24)
# processing  (23, 110, 4)
# processing  (35, 65, 8)
# processing  (38, 131, 24)
# processing  (47, 125, 4)
# processing  (47, 20, 16)
# processing  (50, 86, 24)
# processing  (29, 140, 4)
# processing  (53, 50, 12)
# processing  (41, 95, 12)
# processing  (26, 71, 28)
# processing  (38, 29, 4)
# processing  (29, 35, 16)
# processing  (20, 41, 32)
# processing  (32, 101, 24)
# processing  (44, 56, 28)
# processing  (20, 146, 20)
# processing  (23, 110, 8)
# processing  (35, 65, 12)
# processing  (47, 125, 8)
# processing  (38, 131, 28)
# processing  (47, 20, 20)
# processing  (29, 140, 8)
# processing  (50, 86, 28)
# processing  (41, 95, 16)
# processing  (53, 50, 16)
# processing  (38, 29, 8)
# processing  (26, 71, 32)
# processing  (29, 35, 20)
# processing  (20, 44, 4)
# processing  (32, 101, 28)
# processing  (20, 146, 24)
# processing  (23, 110, 12)
# processing  (35, 65, 16)
# processing  (44, 56, 32)
# processing  (47, 125, 12)
# processing  (38, 131, 32)
# processing  (38, 29, 12)
# processing  (29, 140, 12)
# processing  (47, 20, 24)
# processing  (53, 50, 20)
# processing  (41, 95, 20)
# processing  (26, 74, 4)
# processing  (50, 86, 32)
# processing  (20, 44, 8)
# processing  (29, 35, 24)
# processing  (20, 146, 28)
# processing  (32, 101, 32)
# processing  (23, 110, 16)
# processing  (44, 59, 4)
# processing  (47, 125, 16)
# processing  (35, 65, 20)
# processing  (38, 134, 4)
# processing  (38, 29, 16)
# processing  (29, 140, 16)
# processing  (47, 20, 28)
# processing  (53, 50, 24)
# processing  (41, 95, 24)
# processing  (26, 74, 8)
# processing  (29, 35, 28)
# processing  (50, 89, 4)
# processing  (20, 146, 32)
# processing  (20, 44, 12)
# processing  (32, 104, 4)
# processing  (44, 59, 8)
# processing  (35, 65, 24)
# processing  (47, 125, 20)
# processing  (23, 110, 20)
# processing  (38, 134, 8)
# processing  (38, 29, 20)
# processing  (29, 140, 20)
# processing  (47, 20, 32)
# processing  (53, 50, 28)
# processing  (41, 95, 28)
# processing  (29, 35, 32)
# processing  (20, 149, 4)
# processing  (20, 44, 16)
# processing  (26, 74, 12)
# processing  (50, 89, 8)
# processing  (32, 104, 8)
# processing  (35, 65, 28)
# processing  (47, 125, 24)
# processing  (44, 59, 12)
# processing  (23, 110, 24)
# processing  (41, 95, 32)
# processing  (38, 29, 24)
# processing  (29, 140, 24)
# processing  (38, 134, 12)
# processing  (47, 23, 4)
# processing  (20, 149, 8)
# processing  (53, 50, 32)
# processing  (29, 38, 4)
# processing  (50, 89, 12)
# processing  (26, 74, 16)
# processing  (20, 44, 20)
# processing  (47, 125, 28)
# processing  (32, 104, 12)
# processing  (35, 65, 32)
# processing  (44, 59, 16)
# processing  (23, 110, 28)
# processing  (41, 98, 4)
# processing  (38, 134, 16)
# processing  (47, 23, 8)
# processing  (38, 29, 28)
# processing  (29, 140, 28)
# processing  (29, 38, 8)
# processing  (53, 53, 4)
# processing  (26, 74, 20)
# processing  (50, 89, 16)
# processing  (32, 104, 16)
# processing  (20, 149, 12)
# processing  (20, 44, 24)
# processing  (47, 125, 32)
# processing  (35, 68, 4)
# processing  (44, 59, 20)
# processing  (23, 110, 32)
# processing  (41, 98, 8)
# processing  (47, 23, 12)
# processing  (38, 29, 32)
# processing  (38, 134, 20)
# processing  (26, 74, 24)
# processing  (53, 53, 8)
# processing  (29, 38, 12)
# processing  (50, 89, 20)
# processing  (32, 104, 20)
# processing  (29, 140, 32)
# processing  (47, 128, 4)
# processing  (20, 149, 16)
# processing  (35, 68, 8)
# processing  (20, 44, 28)
# processing  (23, 113, 4)
# processing  (38, 32, 4)
# processing  (41, 98, 12)
# processing  (38, 134, 24)
# processing  (53, 53, 12)
# processing  (26, 74, 28)
# processing  (47, 23, 16)
# processing  (29, 143, 4)
# processing  (29, 38, 16)
# processing  (35, 68, 12)
# processing  (20, 44, 32)
# processing  (50, 89, 24)
# processing  (20, 149, 20)
# processing  (47, 128, 8)
# processing  (32, 104, 24)
# processing  (23, 113, 8)
# processing  (41, 98, 16)
# processing  (38, 32, 8)
# processing  (47, 23, 20)
# processing  (38, 134, 28)
# processing  (53, 53, 16)
# processing  (35, 68, 16)
# processing  (20, 47, 4)
# processing  (29, 143, 8)
# processing  (50, 89, 28)
# processing  (29, 38, 20)
# processing  (26, 74, 32)
# processing  (32, 104, 28)
# processing  (20, 149, 24)
# processing  (47, 128, 12)
# processing  (41, 98, 20)
# processing  (23, 113, 12)
# processing  (38, 32, 12)
# processing  (38, 134, 32)
# processing  (35, 68, 20)
# processing  (47, 23, 24)
# processing  (20, 47, 8)
# processing  (29, 38, 24)
# processing  (53, 53, 20)
# processing  (50, 89, 32)
# processing  (20, 149, 28)
# processing  (32, 104, 32)
# processing  (29, 143, 12)
# processing  (26, 77, 4)
# processing  (47, 128, 16)
# processing  (41, 98, 24)
# processing  (38, 32, 16)
# processing  (47, 23, 28)
# processing  (23, 113, 16)
# processing  (38, 137, 4)
# processing  (20, 47, 12)
# processing  (35, 68, 24)
# processing  (53, 53, 24)
# processing  (29, 38, 28)
# processing  (50, 92, 4)
# processing  (20, 149, 32)
# processing  (26, 77, 8)
# processing  (29, 143, 16)
# processing  (32, 107, 4)
# processing  (47, 128, 20)
# processing  (41, 98, 28)
# processing  (47, 23, 32)
# processing  (23, 113, 20)
# processing  (35, 68, 28)
# processing  (38, 32, 20)
# processing  (20, 47, 16)
# processing  (50, 92, 8)
# processing  (38, 137, 8)
# processing  (53, 53, 28)
# processing  (20, 152, 4)
# processing  (32, 107, 8)
# processing  (29, 38, 32)
# processing  (26, 77, 12)
# processing  (29, 143, 20)
# processing  (47, 128, 24)
# processing  (41, 98, 32)
# processing  (47, 26, 4)
# processing  (35, 68, 32)
# processing  (20, 47, 20)
# processing  (32, 107, 12)
# processing  (50, 92, 12)
# processing  (23, 113, 24)
# processing  (38, 32, 24)
# processing  (38, 137, 12)
# processing  (26, 77, 16)
# processing  (29, 41, 4)
# processing  (20, 152, 8)
# processing  (53, 53, 32)
# processing  (29, 143, 24)
# processing  (47, 128, 28)
# processing  (41, 101, 4)
# processing  (35, 71, 4)
# processing  (50, 92, 16)
# processing  (47, 26, 8)
# processing  (20, 47, 24)
# processing  (38, 32, 28)
# processing  (32, 107, 16)
# processing  (38, 137, 16)
# processing  (23, 113, 28)
# processing  (20, 152, 12)
# processing  (29, 143, 28)
# processing  (29, 41, 8)
# processing  (26, 77, 20)
# processing  (53, 56, 4)
# processing  (47, 128, 32)
# processing  (41, 101, 8)
# processing  (50, 92, 20)
# processing  (47, 26, 12)
# processing  (35, 71, 8)
# processing  (38, 32, 32)
# processing  (23, 113, 32)
# processing  (38, 137, 20)
# processing  (32, 107, 20)
# processing  (20, 47, 28)
# processing  (20, 152, 16)
# processing  (29, 143, 32)
# processing  (29, 41, 12)
# processing  (47, 131, 4)
# processing  (53, 56, 8)
# processing  (26, 77, 24)
# processing  (41, 101, 12)
# processing  (50, 92, 24)
# processing  (23, 116, 4)
# processing  (47, 26, 16)
# processing  (35, 71, 12)
# processing  (38, 35, 4)
# processing  (32, 107, 24)
# processing  (20, 47, 32)
# processing  (38, 137, 24)
# processing  (20, 152, 20)
# processing  (29, 41, 16)
# processing  (29, 146, 4)
# processing  (47, 131, 8)
# processing  (53, 56, 12)
# processing  (26, 77, 28)
# processing  (41, 101, 16)
# processing  (50, 92, 28)
# processing  (47, 26, 20)
# processing  (38, 137, 28)
# processing  (20, 152, 24)
# processing  (23, 116, 8)
# processing  (38, 35, 8)
# processing  (35, 71, 16)
# processing  (32, 107, 28)
# processing  (29, 41, 20)
# processing  (20, 50, 4)
# processing  (29, 146, 8)
# processing  (47, 131, 12)
# processing  (53, 56, 16)
# processing  (26, 77, 32)
# processing  (41, 101, 20)
# processing  (47, 26, 24)
# processing  (50, 92, 32)
# processing  (38, 137, 32)
# processing  (20, 152, 28)
# processing  (38, 35, 12)
# processing  (32, 107, 32)
# processing  (23, 116, 12)
# processing  (29, 41, 24)
# processing  (20, 50, 8)
# processing  (29, 146, 12)
# processing  (35, 71, 20)
# processing  (47, 131, 16)
# processing  (26, 80, 4)
# processing  (53, 56, 20)
# processing  (41, 101, 24)
# processing  (47, 26, 28)
# processing  (50, 95, 4)
# processing  (38, 35, 16)
# processing  (38, 140, 4)
# processing  (20, 152, 32)
# processing  (32, 110, 4)
# processing  (29, 41, 28)
# processing  (23, 116, 16)
# processing  (35, 71, 24)
# processing  (29, 146, 16)
# processing  (47, 131, 20)
# processing  (20, 50, 12)
# processing  (26, 80, 8)
# processing  (41, 101, 28)
# processing  (53, 56, 24)
# processing  (47, 26, 32)
# processing  (38, 140, 8)
# processing  (20, 155, 4)
# processing  (38, 35, 20)
# processing  (50, 95, 8)
# processing  (29, 41, 32)
# processing  (32, 110, 8)
# processing  (29, 146, 20)
# processing  (23, 116, 20)
# processing  (35, 71, 28)
# processing  (26, 80, 12)
# processing  (47, 131, 24)
# processing  (20, 50, 16)
# processing  (41, 101, 32)
# processing  (53, 56, 28)
# processing  (47, 29, 4)
# processing  (38, 35, 24)
# processing  (20, 155, 8)
# processing  (50, 95, 12)
# processing  (38, 140, 12)
# processing  (29, 44, 4)
# processing  (32, 110, 12)
# processing  (23, 116, 24)
# processing  (29, 146, 24)
# processing  (47, 131, 28)
# processing  (20, 50, 20)
# processing  (35, 71, 32)
# processing  (26, 80, 16)
# processing  (41, 104, 4)
# processing  (53, 56, 32)
# processing  (47, 29, 8)
# processing  (38, 35, 28)
# processing  (38, 140, 16)
# processing  (29, 44, 8)
# processing  (20, 155, 12)
# processing  (32, 110, 16)
# processing  (50, 95, 16)
# processing  (23, 116, 28)
# processing  (47, 131, 32)
# processing  (29, 146, 28)
# processing  (20, 50, 24)
# processing  (35, 74, 4)
# processing  (26, 80, 20)
# processing  (53, 59, 4)
# processing  (41, 104, 8)
# processing  (47, 29, 12)
# processing  (38, 35, 32)
# processing  (38, 140, 20)
# processing  (29, 44, 12)
# processing  (32, 110, 20)
# processing  (20, 155, 16)
# processing  (47, 134, 4)
# processing  (35, 74, 8)
# processing  (23, 116, 32)
# processing  (20, 50, 28)
# processing  (29, 146, 32)
# processing  (50, 95, 20)
# processing  (26, 80, 24)
# processing  (41, 104, 12)
# processing  (53, 59, 8)
# processing  (47, 29, 16)
# processing  (29, 44, 16)
# processing  (38, 140, 24)
# processing  (38, 38, 4)
# processing  (32, 110, 24)
# processing  (20, 155, 20)
# processing  (35, 74, 12)
# processing  (23, 119, 4)
# processing  (47, 134, 8)
# processing  (20, 50, 32)
# processing  (26, 80, 28)
# processing  (29, 149, 4)
# processing  (41, 104, 16)
# processing  (50, 95, 24)
# processing  (53, 59, 12)
# processing  (38, 38, 8)
# processing  (47, 29, 20)
# processing  (29, 44, 20)
# processing  (38, 140, 28)
# processing  (35, 74, 16)
# processing  (47, 134, 12)
# processing  (32, 110, 28)
# processing  (20, 155, 24)
# processing  (20, 53, 4)
# processing  (26, 80, 32)
# processing  (23, 119, 8)
# processing  (29, 149, 8)
# processing  (50, 95, 28)
# processing  (41, 104, 20)
# processing  (53, 59, 16)
# processing  (38, 140, 32)
# processing  (38, 38, 12)
# processing  (47, 29, 24)
# processing  (29, 44, 24)
# processing  (20, 155, 28)
# processing  (35, 74, 20)
# processing  (23, 119, 12)
# processing  (47, 134, 16)
# processing  (20, 53, 8)
# processing  (32, 110, 32)
# processing  (26, 83, 4)
# processing  (50, 95, 32)
# processing  (41, 104, 24)
# processing  (29, 149, 12)
# processing  (53, 59, 20)
# processing  (38, 143, 4)
# processing  (29, 44, 28)
# processing  (47, 29, 28)
# processing  (35, 74, 24)
# processing  (38, 38, 16)
# processing  (47, 134, 20)
# processing  (20, 155, 32)
# processing  (23, 119, 16)
# processing  (20, 53, 12)
# processing  (32, 113, 4)
# processing  (26, 83, 8)
# processing  (41, 104, 28)
# processing  (50, 98, 4)
# processing  (29, 149, 16)
# processing  (38, 143, 8)
# processing  (53, 59, 24)
# processing  (47, 29, 32)
# processing  (29, 44, 32)
# processing  (38, 38, 20)
# processing  (35, 74, 28)
# processing  (47, 134, 24)
# processing  (20, 158, 4)
# processing  (20, 53, 16)
# processing  (23, 119, 20)
# processing  (32, 113, 8)
# processing  (26, 83, 12)
# processing  (41, 104, 32)
# processing  (50, 98, 8)
# processing  (29, 149, 20)
# processing  (38, 143, 12)
# processing  (53, 59, 28)
# processing  (35, 74, 32)
# processing  (47, 32, 4)
# processing  (38, 38, 24)
# processing  (47, 134, 28)
# processing  (20, 158, 8)
# processing  (20, 53, 20)
# processing  (23, 119, 24)
# processing  (32, 113, 12)
# processing  (26, 83, 16)
# processing  (41, 107, 4)
# processing  (50, 98, 12)
# processing  (29, 149, 24)
# processing  (38, 143, 16)
# processing  (53, 59, 32)
# processing  (47, 32, 8)
# processing  (35, 77, 4)
# processing  (20, 158, 12)
# processing  (47, 134, 32)
# processing  (38, 38, 28)
# processing  (20, 53, 24)
# processing  (23, 119, 28)
# processing  (32, 113, 16)
# processing  (41, 107, 8)
# processing  (26, 83, 20)
# processing  (50, 98, 16)
# processing  (29, 149, 28)
# processing  (38, 143, 20)
# processing  (53, 62, 4)
# processing  (35, 77, 8)
# processing  (20, 158, 16)
# processing  (47, 32, 12)
# processing  (20, 53, 28)
# processing  (38, 38, 32)
# processing  (47, 137, 4)
# processing  (23, 119, 32)
# processing  (32, 113, 20)
# processing  (41, 107, 12)
# processing  (26, 83, 24)
# processing  (38, 143, 24)
# processing  (29, 149, 32)
# processing  (50, 98, 20)
# processing  (53, 62, 8)
# processing  (20, 158, 20)
# processing  (47, 32, 16)
# processing  (20, 53, 32)
# processing  (35, 77, 12)
# processing  (38, 41, 4)
# processing  (47, 137, 8)
# processing  (23, 122, 4)
# processing  (32, 113, 24)
# processing  (41, 107, 16)
# processing  (29, 152, 4)
# processing  (50, 98, 24)
# processing  (38, 143, 28)
# processing  (26, 83, 28)
# processing  (53, 62, 12)
# processing  (20, 56, 4)
# processing  (47, 32, 20)
# processing  (20, 158, 24)
# processing  (38, 41, 8)
# processing  (47, 137, 12)
# processing  (35, 77, 16)
# processing  (23, 122, 8)
# processing  (32, 113, 28)
# processing  (29, 152, 8)
# processing  (41, 107, 20)
# processing  (50, 98, 28)
# processing  (38, 143, 32)
# processing  (26, 83, 32)
# processing  (38, 41, 12)
# processing  (47, 32, 24)
# processing  (53, 62, 16)
# processing  (20, 56, 8)
# processing  (20, 158, 28)
# processing  (47, 137, 16)
# processing  (35, 77, 20)
# processing  (23, 122, 12)
# processing  (32, 113, 32)
# processing  (29, 152, 12)
# processing  (50, 98, 32)
# processing  (41, 107, 24)
# processing  (38, 146, 4)
# processing  (38, 41, 16)
# processing  (26, 86, 4)
# processing  (53, 62, 20)
# processing  (20, 56, 12)
# processing  (47, 32, 28)
# processing  (20, 158, 32)
# processing  (35, 77, 24)
# processing  (47, 137, 20)
# processing  (32, 116, 4)
# processing  (23, 122, 16)
# processing  (50, 101, 4)
# processing  (29, 152, 16)
# processing  (38, 146, 8)
# processing  (41, 107, 28)
# processing  (38, 41, 20)
# processing  (53, 62, 24)
# processing  (26, 86, 8)
# processing  (20, 56, 16)
# processing  (47, 32, 32)
# processing  (23, 20, 4)
# processing  (35, 77, 28)
# processing  (47, 137, 24)
# processing  (32, 116, 8)
# processing  (50, 101, 8)
# processing  (23, 122, 20)
# processing  (38, 146, 12)
# processing  (29, 152, 20)
# processing  (38, 41, 24)
# processing  (41, 107, 32)
# processing  (53, 62, 28)
# processing  (35, 77, 32)
# processing  (47, 35, 4)
# processing  (26, 86, 12)
# processing  (20, 56, 20)
# processing  (23, 20, 8)
# processing  (47, 137, 28)
# processing  (32, 116, 12)
# processing  (50, 101, 12)
# processing  (23, 122, 24)
# processing  (38, 146, 16)
# processing  (29, 152, 24)
# processing  (38, 41, 28)
# processing  (41, 110, 4)
# processing  (20, 56, 24)
# processing  (23, 20, 12)
# processing  (53, 62, 32)
# processing  (35, 80, 4)
# processing  (26, 86, 16)
# processing  (47, 137, 32)
# processing  (47, 35, 8)
# processing  (32, 116, 16)
# processing  (23, 122, 28)
# processing  (38, 146, 20)
# processing  (29, 152, 28)
# processing  (50, 101, 16)
# processing  (23, 20, 16)
# processing  (38, 41, 32)
# processing  (20, 56, 28)
# processing  (41, 110, 8)
# processing  (53, 65, 4)
# processing  (35, 80, 8)
# processing  (26, 86, 20)
# processing  (47, 140, 4)
# processing  (47, 35, 12)
# processing  (32, 116, 20)
# processing  (23, 122, 32)
# processing  (38, 146, 24)
# processing  (50, 101, 20)
# processing  (29, 152, 32)
# processing  (20, 56, 32)
# processing  (53, 65, 8)
# processing  (26, 86, 24)
# processing  (23, 20, 20)
# processing  (35, 80, 12)
# processing  (41, 110, 12)
# processing  (38, 44, 4)
# processing  (47, 35, 16)
# processing  (47, 140, 8)
# processing  (32, 116, 24)
# processing  (23, 125, 4)
# processing  (53, 65, 12)
# processing  (38, 146, 28)
# processing  (50, 101, 24)
# processing  (29, 155, 4)
# processing  (20, 59, 4)
# processing  (23, 20, 24)
# processing  (47, 35, 20)
# processing  (26, 86, 28)
# processing  (35, 80, 16)
# processing  (41, 110, 16)
# processing  (38, 44, 8)
# processing  (47, 140, 12)
# processing  (32, 116, 28)
# processing  (23, 125, 8)
# processing  (53, 65, 16)
# processing  (38, 146, 32)
# processing  (29, 155, 8)
# processing  (35, 80, 20)
# processing  (23, 20, 28)
# processing  (47, 35, 24)
# processing  (20, 59, 8)
# processing  (50, 101, 28)
# processing  (26, 86, 32)
# processing  (41, 110, 20)
# processing  (38, 44, 12)
# processing  (47, 140, 16)
# processing  (32, 116, 32)
# processing  (23, 125, 12)
# processing  (53, 65, 20)
# processing  (35, 80, 24)
# processing  (29, 155, 12)
# processing  (38, 149, 4)
# processing  (23, 20, 32)
# processing  (47, 35, 28)
# processing  (41, 110, 24)
# processing  (26, 89, 4)
# processing  (38, 44, 16)
# processing  (50, 101, 32)
# processing  (20, 59, 12)
# processing  (47, 140, 20)
# processing  (32, 119, 4)
# processing  (38, 149, 8)
# processing  (23, 125, 16)
# processing  (29, 155, 16)
# processing  (41, 110, 28)
# processing  (53, 65, 24)
# processing  (35, 80, 28)
# processing  (47, 35, 32)
# processing  (38, 44, 20)
# processing  (50, 104, 4)
# processing  (20, 59, 16)
# processing  (47, 140, 24)
# processing  (23, 23, 4)
# processing  (26, 89, 8)
# processing  (32, 119, 8)
# processing  (38, 149, 12)
# processing  (41, 110, 32)
# processing  (53, 65, 28)
# processing  (29, 155, 20)
# processing  (23, 125, 20)
# processing  (50, 104, 8)
# processing  (38, 44, 24)
# processing  (47, 38, 4)
# processing  (35, 80, 32)
# processing  (47, 140, 28)
# processing  (20, 59, 20)
# processing  (23, 23, 8)
# processing  (32, 119, 12)
# processing  (26, 89, 12)
# processing  (41, 113, 4)
# processing  (23, 125, 24)
# processing  (47, 38, 8)
# processing  (53, 65, 32)
# processing  (20, 59, 24)
# processing  (29, 155, 24)
# processing  (50, 104, 12)
# processing  (38, 149, 16)
# processing  (35, 83, 4)
# processing  (38, 44, 28)
# processing  (32, 119, 16)
# processing  (47, 140, 32)
# processing  (23, 23, 12)
# processing  (26, 89, 16)
# processing  (23, 125, 28)
# processing  (47, 38, 12)
# processing  (29, 155, 28)
# processing  (20, 59, 28)
# processing  (50, 104, 16)
# processing  (41, 113, 8)
# processing  (32, 119, 20)
# processing  (35, 83, 8)
# processing  (53, 68, 4)
# processing  (47, 143, 4)
# processing  (38, 149, 20)
# processing  (38, 44, 32)
# processing  (26, 89, 20)
# processing  (23, 23, 16)
# processing  (20, 59, 32)
# processing  (29, 155, 32)
# processing  (50, 104, 20)
# processing  (47, 38, 16)
# processing  (41, 113, 12)
# processing  (23, 125, 32)
# processing  (35, 83, 12)
# processing  (53, 68, 8)
# processing  (32, 119, 24)
# processing  (38, 149, 24)
# processing  (26, 89, 24)
# processing  (47, 143, 8)
# processing  (23, 23, 20)
# processing  (38, 47, 4)
# processing  (20, 62, 4)
# processing  (29, 158, 4)
# processing  (47, 38, 20)
# processing  (53, 68, 12)
# processing  (23, 128, 4)
# processing  (35, 83, 16)
# processing  (50, 104, 24)
# processing  (41, 113, 16)
# processing  (26, 89, 28)
# processing  (32, 119, 28)
# processing  (38, 149, 28)
# processing  (23, 23, 24)
# processing  (38, 47, 8)
# processing  (47, 143, 12)
# processing  (20, 62, 8)
# processing  (29, 158, 8)
# processing  (47, 38, 24)
# processing  (53, 68, 16)
# processing  (23, 128, 8)
# processing  (50, 104, 28)
# processing  (26, 89, 32)
# processing  (32, 119, 32)
# processing  (41, 113, 20)
# processing  (38, 149, 32)
# processing  (35, 83, 20)
# processing  (47, 143, 16)
# processing  (23, 23, 28)
# processing  (38, 47, 12)
# processing  (20, 62, 12)
# processing  (53, 68, 20)
# processing  (47, 38, 28)
# processing  (29, 158, 12)
# processing  (23, 128, 12)
# processing  (26, 92, 4)
# processing  (50, 104, 32)
# processing  (32, 122, 4)
# processing  (38, 152, 4)
# processing  (41, 113, 24)
# processing  (35, 83, 24)
# processing  (47, 143, 20)
# processing  (23, 23, 32)
# processing  (38, 47, 16)
# processing  (53, 68, 24)
# processing  (20, 62, 16)
# processing  (47, 38, 32)
# processing  (29, 158, 16)
# processing  (50, 107, 4)
# processing  (38, 152, 8)
# processing  (32, 122, 8)
# processing  (26, 92, 8)
# processing  (23, 128, 16)
# processing  (41, 113, 28)
# processing  (35, 83, 28)
# processing  (23, 26, 4)
# processing  (38, 47, 20)
# processing  (47, 143, 24)
# processing  (53, 68, 28)
# processing  (47, 41, 4)
# processing  (20, 62, 20)
# processing  (29, 158, 20)
# processing  (50, 107, 8)
# processing  (26, 92, 12)
# processing  (32, 122, 12)
# processing  (38, 152, 12)
# processing  (23, 128, 20)
# processing  (23, 26, 8)
# processing  (41, 113, 32)
# processing  (35, 83, 32)
# processing  (38, 47, 24)
# processing  (47, 143, 28)
# processing  (53, 68, 32)
# processing  (47, 41, 8)
# processing  (20, 62, 24)
# processing  (26, 92, 16)
# processing  (29, 158, 24)
# processing  (50, 107, 12)
# processing  (41, 116, 4)
# processing  (38, 152, 16)
# processing  (32, 122, 16)
# processing  (23, 128, 24)
# processing  (35, 86, 4)
# processing  (23, 26, 12)
# processing  (38, 47, 28)
# processing  (47, 143, 32)
# processing  (53, 71, 4)
# processing  (47, 41, 12)
# processing  (20, 62, 28)
# processing  (29, 158, 28)
# processing  (26, 92, 20)
# processing  (50, 107, 16)
# processing  (32, 122, 20)
# processing  (41, 116, 8)
# processing  (38, 47, 32)
# processing  (23, 26, 16)
# processing  (38, 152, 20)
# processing  (35, 86, 8)
# processing  (23, 128, 28)
# processing  (47, 146, 4)
# processing  (53, 71, 8)
# processing  (47, 41, 16)
# processing  (26, 92, 24)
# processing  (20, 62, 32)
# processing  (29, 158, 32)
# processing  (50, 107, 20)
# processing  (41, 116, 12)
# processing  (38, 152, 24)
# processing  (32, 122, 24)
# processing  (38, 50, 4)
# processing  (23, 26, 20)
# processing  (23, 128, 32)
# processing  (35, 86, 12)
# processing  (47, 146, 8)
# processing  (47, 41, 20)
# processing  (26, 92, 28)
# processing  (20, 65, 4)
# processing  (53, 71, 12)
# processing  (32, 20, 4)
# processing  (50, 107, 24)
# processing  (41, 116, 16)
# processing  (23, 26, 24)
# processing  (23, 131, 4)
# processing  (32, 122, 28)
# processing  (38, 152, 28)
# processing  (38, 50, 8)
# processing  (35, 86, 16)
# processing  (47, 146, 12)
# processing  (47, 41, 24)
# processing  (20, 65, 8)
# processing  (26, 92, 32)
# processing  (32, 20, 8)
# processing  (53, 71, 16)
# processing  (50, 107, 28)
# processing  (23, 131, 8)
# processing  (41, 116, 20)
# processing  (32, 122, 32)
# processing  (23, 26, 28)
# processing  (38, 152, 32)
# processing  (35, 86, 20)
# processing  (38, 50, 12)
# processing  (47, 146, 16)
# processing  (47, 41, 28)
# processing  (26, 95, 4)
# processing  (32, 20, 12)
# processing  (20, 65, 12)
# processing  (23, 131, 12)
# processing  (53, 71, 20)
# processing  (50, 107, 32)
# processing  (32, 125, 4)
# processing  (41, 116, 24)
# processing  (35, 86, 24)
# processing  (38, 155, 4)
# processing  (23, 26, 32)
# processing  (47, 146, 20)
# processing  (38, 50, 16)
# processing  (47, 41, 32)
# processing  (32, 20, 16)
# processing  (20, 65, 16)
# processing  (26, 95, 8)
# processing  (23, 131, 16)
# processing  (53, 71, 24)
# processing  (32, 125, 8)
# processing  (50, 110, 4)
# processing  (38, 155, 8)
# processing  (41, 116, 28)
# processing  (23, 29, 4)
# processing  (35, 86, 28)
# processing  (47, 146, 24)
# processing  (38, 50, 20)
# processing  (47, 44, 4)
# processing  (32, 20, 20)
# processing  (23, 131, 20)
# processing  (20, 65, 20)
# processing  (32, 125, 12)
# processing  (38, 155, 12)
# processing  (53, 71, 28)
# processing  (26, 95, 12)
# processing  (50, 110, 8)
# processing  (35, 86, 32)
# ...
# processing  (155, 53, 4)
# processing  (158, 116, 24)
# processing  (152, 89, 24)
# processing  (155, 155, 32)
# processing  (155, 53, 8)
# processing  (158, 116, 28)
# processing  (152, 89, 28)
# processing  (155, 158, 4)
# processing  (155, 53, 12)
# processing  (158, 116, 32)
# processing  (152, 89, 32)
# processing  (155, 53, 16)
# processing  (155, 158, 8)
# processing  (158, 119, 4)
# processing  (152, 92, 4)
# processing  (155, 53, 20)
# processing  (155, 158, 12)
# processing  (158, 119, 8)
# processing  (152, 92, 8)
# processing  (155, 53, 24)
# processing  (155, 158, 16)
# processing  (158, 119, 12)
# processing  (152, 92, 12)
# processing  (155, 53, 28)
# processing  (155, 158, 20)
# processing  (158, 119, 16)
# processing  (152, 92, 16)
# processing  (155, 53, 32)
# processing  (158, 119, 20)
# processing  (155, 158, 24)
# processing  (152, 92, 20)
# processing  (155, 56, 4)
# processing  (155, 158, 28)
# processing  (158, 119, 24)
# processing  (152, 92, 24)
# processing  (155, 56, 8)
# processing  (158, 119, 28)
# processing  (155, 158, 32)
# processing  (152, 92, 28)
# processing  (155, 56, 12)
# processing  (158, 119, 32)
# processing  (158, 20, 4)
# processing  (152, 92, 32)
# processing  (155, 56, 16)
# processing  (158, 122, 4)
# processing  (158, 20, 8)
# processing  (152, 95, 4)
# processing  (155, 56, 20)
# processing  (158, 122, 8)
# processing  (158, 20, 12)
# processing  (152, 95, 8)
# processing  (155, 56, 24)
# processing  (158, 122, 12)
# processing  (158, 20, 16)
# processing  (152, 95, 12)
# processing  (155, 56, 28)
# processing  (158, 122, 16)
# processing  (158, 20, 20)
# processing  (152, 95, 16)
# processing  (155, 56, 32)
# processing  (158, 122, 20)
# processing  (158, 20, 24)
# processing  (152, 95, 20)
# processing  (155, 59, 4)
# processing  (158, 122, 24)
# processing  (158, 20, 28)
# processing  (152, 95, 24)
# processing  (158, 122, 28)
# processing  (155, 59, 8)
# processing  (158, 20, 32)
# processing  (158, 122, 32)
# processing  (152, 95, 28)
# processing  (155, 59, 12)
# processing  (158, 23, 4)
# processing  (158, 125, 4)
# processing  (155, 59, 16)
# processing  (152, 95, 32)
# processing  (152, 98, 4)
# processing  (158, 23, 8)
# processing  (158, 125, 8)
# processing  (155, 59, 20)
# processing  (158, 23, 12)
# processing  (152, 98, 8)
# processing  (158, 125, 12)
# processing  (155, 59, 24)
# processing  (152, 98, 12)
# processing  (158, 125, 16)
# processing  (158, 23, 16)
# processing  (155, 59, 28)
# processing  (152, 98, 16)
# processing  (158, 23, 20)
# processing  (158, 125, 20)
# processing  (155, 59, 32)
# processing  (152, 98, 20)
# processing  (158, 125, 24)
# processing  (158, 23, 24)
# processing  (155, 62, 4)
# processing  (152, 98, 24)
# processing  (158, 23, 28)
# processing  (158, 125, 28)
# processing  (155, 62, 8)
# processing  (152, 98, 28)
# processing  (158, 23, 32)
# processing  (158, 125, 32)
# processing  (155, 62, 12)
# processing  (152, 98, 32)
# processing  (158, 128, 4)
# processing  (158, 26, 4)
# processing  (155, 62, 16)
# processing  (152, 101, 4)
# processing  (158, 128, 8)
# processing  (158, 26, 8)
# processing  (155, 62, 20)
# processing  (152, 101, 8)
# processing  (158, 128, 12)
# processing  (158, 26, 12)
# processing  (155, 62, 24)
# processing  (152, 101, 12)
# processing  (158, 128, 16)
# processing  (158, 26, 16)
# processing  (155, 62, 28)
# processing  (152, 101, 16)
# processing  (158, 128, 20)
# processing  (158, 26, 20)
# processing  (155, 62, 32)
# processing  (158, 128, 24)
# processing  (152, 101, 20)
# processing  (158, 26, 24)
# processing  (155, 65, 4)
# processing  (152, 101, 24)
# processing  (158, 128, 28)
# processing  (158, 26, 28)
# processing  (155, 65, 8)
# processing  (158, 128, 32)
# processing  (152, 101, 28)
# processing  (158, 26, 32)
# processing  (155, 65, 12)
# processing  (158, 131, 4)
# processing  (152, 101, 32)
# processing  (158, 29, 4)
# processing  (155, 65, 16)
# processing  (158, 131, 8)
# processing  (152, 104, 4)
# processing  (155, 65, 20)
# processing  (158, 29, 8)
# processing  (152, 104, 8)
# processing  (158, 29, 12)
# processing  (158, 131, 12)
# processing  (155, 65, 24)
# processing  (158, 29, 16)
# processing  (152, 104, 12)
# processing  (158, 131, 16)
# processing  (155, 65, 28)
# processing  (152, 104, 16)
# processing  (158, 29, 20)
# processing  (155, 65, 32)
# processing  (158, 131, 20)
# processing  (152, 104, 20)
# processing  (158, 29, 24)
# processing  (155, 68, 4)
# processing  (158, 131, 24)
# processing  (152, 104, 24)
# processing  (155, 68, 8)
# processing  (158, 29, 28)
# processing  (158, 131, 28)
# processing  (152, 104, 28)
# processing  (158, 29, 32)
# processing  (155, 68, 12)
# processing  (158, 131, 32)
# processing  (152, 104, 32)
# processing  (155, 68, 16)
# processing  (158, 32, 4)
# processing  (158, 134, 4)
# processing  (155, 68, 20)
# processing  (158, 32, 8)
# processing  (158, 134, 8)
# processing  (152, 107, 4)
# processing  (155, 68, 24)
# processing  (158, 32, 12)
# processing  (152, 107, 8)
# processing  (158, 134, 12)
# processing  (155, 68, 28)
# processing  (158, 32, 16)
# processing  (152, 107, 12)
# processing  (158, 134, 16)
# processing  (155, 68, 32)
# processing  (158, 32, 20)
# processing  (152, 107, 16)
# processing  (158, 134, 20)
# processing  (155, 71, 4)
# processing  (158, 32, 24)
# processing  (152, 107, 20)
# processing  (158, 134, 24)
# processing  (155, 71, 8)
# processing  (158, 32, 28)
# processing  (152, 107, 24)
# processing  (158, 134, 28)
# processing  (155, 71, 12)
# processing  (158, 32, 32)
# processing  (152, 107, 28)
# processing  (158, 134, 32)
# processing  (155, 71, 16)
# processing  (158, 35, 4)
# processing  (152, 107, 32)
# processing  (158, 137, 4)
# processing  (155, 71, 20)
# processing  (158, 35, 8)
# processing  (152, 110, 4)
# processing  (158, 137, 8)
# processing  (155, 71, 24)
# processing  (158, 35, 12)
# processing  (152, 110, 8)
# processing  (158, 137, 12)
# processing  (155, 71, 28)
# processing  (158, 35, 16)
# processing  (152, 110, 12)
# processing  (158, 137, 16)
# processing  (155, 71, 32)
# processing  (158, 35, 20)
# processing  (152, 110, 16)
# processing  (155, 74, 4)
# processing  (158, 137, 20)
# processing  (158, 35, 24)
# processing  (152, 110, 20)
# processing  (155, 74, 8)
# processing  (158, 137, 24)
# processing  (158, 35, 28)
# processing  (152, 110, 24)
# processing  (155, 74, 12)
# processing  (158, 137, 28)
# processing  (158, 35, 32)
# processing  (152, 110, 28)
# processing  (155, 74, 16)
# processing  (158, 137, 32)
# processing  (158, 38, 4)
# processing  (152, 110, 32)
# processing  (158, 140, 4)
# processing  (155, 74, 20)
# processing  (158, 38, 8)
# processing  (152, 113, 4)
# processing  (158, 140, 8)
# processing  (155, 74, 24)
# processing  (158, 38, 12)
# processing  (152, 113, 8)
# processing  (158, 140, 12)
# processing  (155, 74, 28)
# processing  (158, 38, 16)
# processing  (152, 113, 12)
# processing  (155, 74, 32)
# processing  (158, 140, 16)
# processing  (158, 38, 20)
# processing  (152, 113, 16)
# processing  (155, 77, 4)
# processing  (158, 140, 20)
# processing  (158, 38, 24)
# processing  (152, 113, 20)
# processing  (155, 77, 8)
# processing  (158, 140, 24)
# processing  (158, 38, 28)
# processing  (152, 113, 24)
# processing  (155, 77, 12)
# processing  (158, 140, 28)
# processing  (158, 38, 32)
# processing  (158, 140, 32)
# processing  (155, 77, 16)
# processing  (152, 113, 28)
# processing  (158, 41, 4)
# processing  (158, 143, 4)
# processing  (152, 113, 32)
# processing  (155, 77, 20)
# processing  (158, 41, 8)
# processing  (158, 143, 8)
# processing  (155, 77, 24)
# processing  (152, 116, 4)
# processing  (158, 41, 12)
# processing  (158, 143, 12)
# processing  (155, 77, 28)
# processing  (152, 116, 8)
# processing  (158, 41, 16)
# processing  (158, 143, 16)
# processing  (155, 77, 32)
# processing  (158, 41, 20)
# processing  (152, 116, 12)
# processing  (158, 143, 20)
# processing  (155, 80, 4)
# processing  (158, 41, 24)
# processing  (152, 116, 16)
# processing  (158, 143, 24)
# processing  (155, 80, 8)
# processing  (158, 41, 28)
# processing  (152, 116, 20)
# processing  (158, 143, 28)
# processing  (155, 80, 12)
# processing  (158, 41, 32)
# processing  (152, 116, 24)
# processing  (158, 143, 32)
# processing  (155, 80, 16)
# processing  (158, 44, 4)
# processing  (152, 116, 28)
# processing  (158, 146, 4)
# processing  (155, 80, 20)
# processing  (158, 44, 8)
# processing  (152, 116, 32)
# processing  (158, 146, 8)
# processing  (155, 80, 24)
# processing  (158, 44, 12)
# processing  (152, 119, 4)
# processing  (158, 146, 12)
# processing  (155, 80, 28)
# processing  (158, 44, 16)
# processing  (152, 119, 8)
# processing  (158, 146, 16)
# processing  (155, 80, 32)
# processing  (158, 44, 20)
# processing  (152, 119, 12)
# processing  (158, 146, 20)
# processing  (155, 83, 4)
# processing  (158, 44, 24)
# processing  (152, 119, 16)
# processing  (158, 146, 24)
# processing  (155, 83, 8)
# processing  (158, 44, 28)
# processing  (152, 119, 20)
# processing  (158, 146, 28)
# processing  (155, 83, 12)
# processing  (158, 44, 32)
# processing  (152, 119, 24)
# processing  (158, 146, 32)
# processing  (158, 47, 4)
# processing  (155, 83, 16)
# processing  (152, 119, 28)
# processing  (158, 149, 4)
# processing  (158, 47, 8)
# processing  (155, 83, 20)
# processing  (152, 119, 32)
# processing  (158, 149, 8)
# processing  (155, 83, 24)
# processing  (158, 47, 12)
# processing  (152, 122, 4)
# processing  (158, 149, 12)
# processing  (155, 83, 28)
# processing  (158, 47, 16)
# processing  (152, 122, 8)
# processing  (158, 149, 16)
# processing  (155, 83, 32)
# processing  (158, 47, 20)
# processing  (152, 122, 12)
# processing  (158, 149, 20)
# processing  (155, 86, 4)
# processing  (158, 47, 24)
# processing  (152, 122, 16)
# processing  (158, 149, 24)
# processing  (155, 86, 8)
# processing  (158, 47, 28)
# processing  (152, 122, 20)
# processing  (158, 149, 28)
# processing  (155, 86, 12)
# processing  (158, 47, 32)
# processing  (152, 122, 24)
# processing  (158, 149, 32)
# processing  (155, 86, 16)
# processing  (158, 50, 4)
# processing  (152, 122, 28)
# processing  (158, 152, 4)
# processing  (155, 86, 20)
# processing  (158, 50, 8)
# processing  (152, 122, 32)
# processing  (155, 86, 24)
# processing  (158, 152, 8)
# processing  (158, 50, 12)
# processing  (152, 125, 4)
# processing  (155, 86, 28)
# processing  (158, 152, 12)
# processing  (158, 50, 16)
# processing  (152, 125, 8)
# processing  (155, 86, 32)
# processing  (158, 152, 16)
# processing  (158, 50, 20)
# processing  (152, 125, 12)
# processing  (155, 89, 4)
# processing  (158, 152, 20)
# processing  (158, 50, 24)
# processing  (152, 125, 16)
# processing  (155, 89, 8)
# processing  (158, 50, 28)
# processing  (158, 152, 24)
# processing  (152, 125, 20)
# processing  (155, 89, 12)
# processing  (158, 50, 32)
# processing  (158, 152, 28)
# processing  (152, 125, 24)
# processing  (155, 89, 16)
# processing  (158, 152, 32)
# processing  (158, 53, 4)
# processing  (152, 125, 28)
# processing  (155, 89, 20)
# processing  (158, 155, 4)
# processing  (158, 53, 8)
# processing  (152, 125, 32)
# processing  (155, 89, 24)
# processing  (158, 53, 12)
# processing  (158, 155, 8)
# processing  (155, 89, 28)
# processing  (152, 128, 4)
# processing  (158, 53, 16)
# processing  (158, 155, 12)
# processing  (155, 89, 32)
# processing  (152, 128, 8)
# processing  (158, 53, 20)
# processing  (158, 155, 16)
# processing  (155, 92, 4)
# processing  (158, 53, 24)
# processing  (152, 128, 12)
# processing  (158, 155, 20)
# processing  (158, 53, 28)
# processing  (155, 92, 8)
# processing  (152, 128, 16)
# processing  (158, 155, 24)
# processing  (155, 92, 12)
# processing  (158, 53, 32)
# processing  (152, 128, 20)
# processing  (155, 92, 16)
# processing  (158, 155, 28)
# processing  (158, 56, 4)
# processing  (152, 128, 24)
# processing  (155, 92, 20)
# processing  (158, 155, 32)
# processing  (158, 56, 8)
# processing  (152, 128, 28)
# processing  (155, 92, 24)
# processing  (158, 158, 4)
# processing  (158, 56, 12)
# processing  (152, 128, 32)
# processing  (155, 92, 28)
# processing  (158, 158, 8)
# processing  (158, 56, 16)
# processing  (155, 92, 32)
# processing  (152, 131, 4)
# processing  (158, 158, 12)
# processing  (158, 56, 20)
# processing  (155, 95, 4)
# processing  (152, 131, 8)
# processing  (158, 158, 16)
# processing  (158, 56, 24)
# processing  (152, 131, 12)
# processing  (155, 95, 8)
# processing  (158, 158, 20)
# processing  (158, 56, 28)
# processing  (152, 131, 16)
# processing  (155, 95, 12)
# processing  (158, 56, 32)
# processing  (158, 158, 24)
# processing  (152, 131, 20)
# processing  (155, 95, 16)
# processing  (158, 59, 4)
# processing  (158, 158, 28)
# processing  (152, 131, 24)
# processing  (155, 95, 20)
# processing  (158, 158, 32)
# processing  (158, 59, 8)
# processing  (152, 131, 28)
# processing  (155, 95, 24)
# processing  (158, 59, 12)
# processing  (152, 131, 32)
# processing  (155, 95, 28)
# processing  (152, 134, 4)
# processing  (158, 59, 16)
# processing  (155, 95, 32)
# processing  (152, 134, 8)
# processing  (158, 59, 20)
# processing  (155, 98, 4)
# processing  (158, 59, 24)
# processing  (152, 134, 12)
# processing  (155, 98, 8)
# processing  (158, 59, 28)
# processing  (152, 134, 16)
# processing  (155, 98, 12)
# processing  (152, 134, 20)
# processing  (158, 59, 32)
# processing  (155, 98, 16)
# processing  (158, 62, 4)
# processing  (152, 134, 24)
# processing  (155, 98, 20)
# processing  (158, 62, 8)
# processing  (152, 134, 28)
# processing  (155, 98, 24)
# processing  (152, 134, 32)
# processing  (158, 62, 12)
# processing  (155, 98, 28)
# processing  (158, 62, 16)
# processing  (152, 137, 4)
# processing  (155, 98, 32)
# processing  (158, 62, 20)
# processing  (152, 137, 8)
# processing  (155, 101, 4)
# processing  (158, 62, 24)
# processing  (152, 137, 12)
# processing  (155, 101, 8)
# processing  (152, 137, 16)
# processing  (158, 62, 28)
# processing  (155, 101, 12)
# processing  (158, 62, 32)
# processing  (152, 137, 20)
# processing  (155, 101, 16)
# processing  (158, 65, 4)
# processing  (152, 137, 24)
# processing  (155, 101, 20)
# processing  (152, 137, 28)
# processing  (158, 65, 8)
# processing  (155, 101, 24)
# processing  (152, 137, 32)
# processing  (158, 65, 12)
# processing  (155, 101, 28)
# processing  (152, 140, 4)
# processing  (158, 65, 16)
# processing  (155, 101, 32)
# processing  (152, 140, 8)
# processing  (158, 65, 20)
# processing  (155, 104, 4)
# processing  (152, 140, 12)
# processing  (155, 104, 8)
# processing  (158, 65, 24)
# processing  (152, 140, 16)
# processing  (155, 104, 12)
# processing  (158, 65, 28)
# processing  (152, 140, 20)
# processing  (155, 104, 16)
# processing  (158, 65, 32)
# processing  (152, 140, 24)
# processing  (155, 104, 20)
# processing  (158, 68, 4)
# processing  (152, 140, 28)
# processing  (155, 104, 24)
# processing  (158, 68, 8)
# processing  (152, 140, 32)
# processing  (155, 104, 28)
# processing  (158, 68, 12)
# processing  (152, 143, 4)
# processing  (155, 104, 32)
# processing  (158, 68, 16)
# processing  (152, 143, 8)
# processing  (158, 68, 20)
# processing  (155, 107, 4)
# processing  (152, 143, 12)
# processing  (158, 68, 24)
# processing  (155, 107, 8)
# processing  (152, 143, 16)
# processing  (158, 68, 28)
# processing  (155, 107, 12)
# processing  (152, 143, 20)
# processing  (158, 68, 32)
# processing  (155, 107, 16)
# processing  (152, 143, 24)
# processing  (158, 71, 4)
# processing  (155, 107, 20)
# processing  (152, 143, 28)
# processing  (158, 71, 8)
# processing  (155, 107, 24)
# processing  (152, 143, 32)
# processing  (158, 71, 12)
# processing  (155, 107, 28)
# processing  (152, 146, 4)
# processing  (158, 71, 16)
# processing  (155, 107, 32)
# processing  (152, 146, 8)
# processing  (158, 71, 20)
# processing  (155, 110, 4)
# processing  (152, 146, 12)
# processing  (158, 71, 24)
# processing  (155, 110, 8)
# processing  (152, 146, 16)
# processing  (158, 71, 28)
# processing  (155, 110, 12)
# processing  (152, 146, 20)
# processing  (155, 110, 16)
# processing  (158, 71, 32)
# processing  (152, 146, 24)
# processing  (155, 110, 20)
# processing  (158, 74, 4)
# processing  (152, 146, 28)
# processing  (155, 110, 24)
# processing  (158, 74, 8)
# processing  (152, 146, 32)
# processing  (155, 110, 28)
# processing  (158, 74, 12)
# processing  (152, 149, 4)
# processing  (155, 110, 32)
# processing  (158, 74, 16)
# processing  (152, 149, 8)
# processing  (155, 113, 4)
# processing  (158, 74, 20)
# processing  (152, 149, 12)
# processing  (155, 113, 8)
# processing  (158, 74, 24)
# processing  (152, 149, 16)
# processing  (155, 113, 12)
# processing  (158, 74, 28)
# processing  (158, 74, 32)
# processing  (155, 113, 16)
# processing  (152, 149, 20)
# processing  (158, 77, 4)
# processing  (152, 149, 24)
# processing  (155, 113, 20)
# processing  (158, 77, 8)
# processing  (155, 113, 24)
# processing  (152, 149, 28)
# processing  (158, 77, 12)
# processing  (152, 149, 32)
# processing  (152, 152, 4)

# %%
result = np.array(result)

# %%
result_coord = zip(coordinates, result)

# %%
for i, alpha in enumerate(range(30, 200, 10)):
    title("alpha = {}".format(alpha))
    hist(result[:, i])
    show()

# %%
np.save("result/results2", result_coord)

# %%
print("ok")
